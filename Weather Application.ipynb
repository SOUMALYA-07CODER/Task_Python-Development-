# %%
import requests
val = input('Enter City: ')
url = 'https://wttr.in/{}'.format(val)
response = requests.get(url)
weather_data = response.text
print(weather_data)
# Out:
# Enter City:  London
# Weather report: London
#
#    _`/"".-.     Patchy rain nearby
#     ,\_(   ).   +11(7) °C
#      /(___(__)  ↗ 29 km/h
#        ‘ ‘ ‘ ‘  10 km
#       ‘ ‘ ‘ ‘   0.1 mm
#                                                        ┌─────────────┐
# ┌──────────────────────────────┬───────────────────────┤  Sat 21 Dec ├───────────────────────┬──────────────────────────────┐
# │            Morning           │             Noon      └──────┬──────┘     Evening           │             Night            │
# ├──────────────────────────────┼──────────────────────────────┼──────────────────────────────┼──────────────────────────────┤
# │  _`/"".-.     Patchy rain ne…│               Overcast       │               Cloudy         │    \  /       Partly Cloudy  │
# │   ,\_(   ).   +8(4) °C       │      .--.     +9(6) °C       │      .--.     +9(6) °C       │  _ /"".-.     +8(5) °C       │
# ...
